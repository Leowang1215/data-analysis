# %%
import pandas as pd

# %%
cram_school = pd.read_csv("C:/Users/leow7/OneDrive/桌面/data analysis/sself-learning/cramschool.csv", encoding = 'big5', index_col=1)
# index col
cram_school
# Out:
#      項次  國中補校校數【統計數值】  國中補校班級數【統計數值】  國中補校學生數【統計數值】  國中補校上學年畢業生數【統計數值】  \
# 民國年
# 103   1            12             38            526                129
# 104   2            12             37            482                125
# 106   4            12             37            519                 80
# 107   5            12             36            507                112
# 108   6            12             36            518                107
# 109   7            12             36            439                 84
# 110   8            12             36            425                 85
# 111   9            12             36            396                 91
# 112  10            12             36            408                 71
#
#      國小補校校數【統計數值】  國小補校班級數【統計數值】  國小補校學生數【統計數值】  國小補校上學年畢業生數【統計數值】
# 民國年
# 103            16             73           1258                244
# 104            16             72           1267                338
# ...

# %%
fruits = {"Apple":[30],"Bananas":[21]}
fruits = pd.DataFrame(fruits)

# %%
ind = ["2017 Sales","2018 Sales"]
fruit_sales = {"Apples":[35,41],"Bananas":[21,34]}
fruit_sales = pd.DataFrame(fruit_sales, index =ind)

# %%
pd.Series(["4 cups","1 cup","2 large", "1 can"], index = ["Flour","Milk","Eggs","Spam"], name = "Dinner" )
# Out:
# Flour     4 cups
# Milk       1 cup
# Eggs     2 large
# Spam       1 can
# Name: Dinner, dtype: object

# %%
pd.read_csv
# Out:
# <function pandas.io.parsers.readers.read_csv(filepath_or_buffer: 'FilePath | ReadCsvBuffer[bytes] | ReadCsvBuffer[str]', *, sep: 'str | None | lib.NoDefault' = <no_default>, delimiter: 'str | None | lib.NoDefault' = None, header: "int | Sequence[int] | None | Literal['infer']" = 'infer', names: 'Sequence[Hashable] | None | lib.NoDefault' = <no_default>, index_col: 'IndexLabel | Literal[False] | None' = None, usecols: 'UsecolsArgType' = None, dtype: 'DtypeArg | None' = None, engine: 'CSVEngine | None' = None, converters: 'Mapping[Hashable, Callable] | None' = None, true_values: 'list | None' = None, false_values: 'list | None' = None, skipinitialspace: 'bool' = False, skiprows: 'list[int] | int | Callable[[Hashable], bool] | None' = None, skipfooter: 'int' = 0, nrows: 'int | None' = None, na_values: 'Hashable | Iterable[Hashable] | Mapping[Hashable, Iterable[Hashable]] | None' = None, keep_default_na: 'bool' = True, na_filter: 'bool' = True, verbose: 'bool | lib.NoDefault' = <no_defau
# ...

# %%
cows = pd.DataFrame.to_csv(fruits)

# %% [markdown]
# ### Indexing, Selecting & Assigning## C

# %%
fruit_sales
# Out:
#             Apples  Bananas
# 2017 Sales      35       21
# 2018 Sales      41       34

# %%
fruit_sales.Apples
## 作用相等
fruit_sales["Apples"]
# Out:
# 2017 Sales    35
# 2018 Sales    41
# Name: Apples, dtype: int64

# %%
fruit_sales['Apples'][0]
# Out:
# C:\Users\leow7\AppData\Local\Temp\ipykernel_7896\823875812.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   fruit_sales['Apples'][0]
# np.int64(35)

# %%
fruit_sales.loc['2017 Sales']
#作用一樣
fruit_sales.iloc[0]
# Out:
# Apples     35
# Bananas    21
# Name: 2017 Sales, dtype: int64

# %% [markdown]
# #### iloc, loc ->  row-first, column-second.

# %%
fruit_sales.iloc[0][1]
# Out:
# C:\Users\leow7\AppData\Local\Temp\ipykernel_7896\2451846811.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   fruit_sales.iloc[0][1]
# np.int64(21)

# %%
fruit_sales.iloc[:2,0]
# Out:
# 2017 Sales    35
# 2018 Sales    41
# Name: Apples, dtype: int64

# %% [markdown]
# ## 11/1

# %%
from sklearn import datasets

# %%
cram = pd.read_csv('C:/Users/leow7/OneDrive/桌面/data analysis/sself-learning/cramschool.csv',encoding = 'big5')
cram
# Out:
#    項次  民國年  國中補校校數【統計數值】  國中補校班級數【統計數值】  國中補校學生數【統計數值】  國中補校上學年畢業生數【統計數值】  \
# 0   1  103            12             38            526                129
# 1   2  104            12             37            482                125
# 2   4  106            12             37            519                 80
# 3   5  107            12             36            507                112
# 4   6  108            12             36            518                107
# 5   7  109            12             36            439                 84
# 6   8  110            12             36            425                 85
# 7   9  111            12             36            396                 91
# 8  10  112            12             36            408                 71
#
#    國小補校校數【統計數值】  國小補校班級數【統計數值】  國小補校學生數【統計數值】  國小補校上學年畢業生數【統計數值】
# 0            16             73           1258                244
# 1            16             72           1267                338
# ...

# %%
iris = datasets.load_iris()
print(iris.DESCR, '\n', "keys ",iris.keys())
iris.feature_names
# Out:
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
# :Number of Instances: 150 (50 in each of three classes)
# :Number of Attributes: 4 numeric, predictive attributes and the class
# :Attribute Information:
#     - sepal length in cm
#     - sepal width in cm
#     - petal length in cm
#     - petal width in cm
#     - class:
#             - Iris-Setosa
#             - Iris-Versicolour
#             - Iris-Virginica
#
# :Summary Statistics:
#
# ============== ==== ==== ======= ===== ====================
#                 Min  Max   Mean    SD   Class Correlation
# ============== ==== ==== ======= ===== ====================
# sepal length:   4.3  7.9   5.84   0.83    0.7826
# sepal width:    2.0  4.4   3.05   0.43   -0.4194
# petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
# petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)
# ============== ==== ==== ======= ===== ====================
#
# ...

# %%
target_name_list = []
for i in range(150):
    target_name_list.append(iris.target_names[int(i/50)])
iris_table = pd.DataFrame(iris.data, columns = iris.feature_names, index = target_name_list)
iris_table
# Out:
#            sepal length (cm)  sepal width (cm)  petal length (cm)  \
# setosa                   5.1               3.5                1.4
# setosa                   4.9               3.0                1.4
# setosa                   4.7               3.2                1.3
# setosa                   4.6               3.1                1.5
# setosa                   5.0               3.6                1.4
# ...                      ...               ...                ...
# virginica                6.7               3.0                5.2
# virginica                6.3               2.5                5.0
# virginica                6.5               3.0                5.2
# virginica                6.2               3.4                5.4
# virginica                5.9               3.0                5.1
#
#            petal width (cm)
# setosa                  0.2
# setosa                  0.2
# setosa                  0.2
# setosa                  0.2
# ...

# %%
iris_table.loc['setosa', 'sepal length (cm)']
# Out:
# setosa    5.1
# setosa    4.9
# setosa    4.7
# setosa    4.6
# setosa    5.0
# setosa    5.4
# setosa    4.6
# setosa    5.0
# setosa    4.4
# setosa    4.9
# setosa    5.4
# setosa    4.8
# setosa    4.8
# setosa    4.3
# setosa    5.8
# setosa    5.7
# setosa    5.4
# setosa    5.1
# setosa    5.7
# setosa    5.1
# setosa    5.4
# setosa    5.1
# setosa    4.6
# setosa    5.1
# setosa    4.8
# setosa    5.0
# setosa    5.0
# setosa    5.2
# setosa    5.2
# setosa    4.7
# setosa    4.8
# setosa    5.4
# setosa    5.2
# setosa    5.5
# setosa    4.9
# setosa    5.0
# setosa    5.5
# setosa    4.9
# setosa    4.4
# setosa    5.1
# setosa    5.0
# setosa    4.5
# setosa    4.4
# setosa    5.0
# setosa    5.1
# setosa    4.8
# setosa    5.1
# setosa    4.6
# setosa    5.3
# setosa    5.0
# Name: sepal length (cm), dtype: float64

# %%
iris_table.loc[(iris_table.index == "setosa") & (iris_table["sepal length (cm)"]>5)]
# Out:
#         sepal length (cm)  sepal width (cm)  petal length (cm)  \
# setosa                5.1               3.5                1.4
# setosa                5.4               3.9                1.7
# setosa                5.4               3.7                1.5
# setosa                5.8               4.0                1.2
# setosa                5.7               4.4                1.5
# setosa                5.4               3.9                1.3
# setosa                5.1               3.5                1.4
# setosa                5.7               3.8                1.7
# setosa                5.1               3.8                1.5
# setosa                5.4               3.4                1.7
# setosa                5.1               3.7                1.5
# setosa                5.1               3.3                1.7
# setosa                5.2               3.5                1.5
# setosa                5.2               3.4                1.4
# ...

# %%
iris_table.iloc[0,0]
# Out:
# np.float64(5.1)

# %%
iris_table.loc['setosa',"sepal length (cm)"]
# Out:
# setosa    5.1
# setosa    4.9
# setosa    4.7
# setosa    4.6
# setosa    5.0
# setosa    5.4
# setosa    4.6
# setosa    5.0
# setosa    4.4
# setosa    4.9
# setosa    5.4
# setosa    4.8
# setosa    4.8
# setosa    4.3
# setosa    5.8
# setosa    5.7
# setosa    5.4
# setosa    5.1
# setosa    5.7
# setosa    5.1
# setosa    5.4
# setosa    5.1
# setosa    4.6
# setosa    5.1
# setosa    4.8
# setosa    5.0
# setosa    5.0
# setosa    5.2
# setosa    5.2
# setosa    4.7
# setosa    4.8
# setosa    5.4
# setosa    5.2
# setosa    5.5
# setosa    4.9
# setosa    5.0
# setosa    5.5
# setosa    4.9
# setosa    4.4
# setosa    5.1
# setosa    5.0
# setosa    4.5
# setosa    4.4
# setosa    5.0
# setosa    5.1
# setosa    4.8
# setosa    5.1
# setosa    4.6
# setosa    5.3
# setosa    5.0
# Name: sepal length (cm), dtype: float64

# %%
iris_table.iloc[0:100]
# Out:
#             sepal length (cm)  sepal width (cm)  petal length (cm)  \
# setosa                    5.1               3.5                1.4
# setosa                    4.9               3.0                1.4
# setosa                    4.7               3.2                1.3
# setosa                    4.6               3.1                1.5
# setosa                    5.0               3.6                1.4
# ...                       ...               ...                ...
# versicolor                5.7               3.0                4.2
# versicolor                5.7               2.9                4.2
# versicolor                6.2               2.9                4.3
# versicolor                5.1               2.5                3.0
# versicolor                5.7               2.8                4.1
#
#             petal width (cm)
# setosa                   0.2
# setosa                   0.2
# setosa                   0.2
# setosa                   0.2
# ...

# %%
iris_table.set_index('sepal length (cm)')
# Out:
#                    sepal width (cm)  petal length (cm)  petal width (cm)
# sepal length (cm)
# 5.1                             3.5                1.4               0.2
# 4.9                             3.0                1.4               0.2
# 4.7                             3.2                1.3               0.2
# 4.6                             3.1                1.5               0.2
# 5.0                             3.6                1.4               0.2
# ...                             ...                ...               ...
# 6.7                             3.0                5.2               2.3
# 6.3                             2.5                5.0               1.9
# 6.5                             3.0                5.2               2.0
# 6.2                             3.4                5.4               2.3
# 5.9                             3.0                5.1               1.8
#
# [150 rows x 3 columns]

# %%
iris_table['sepal length (cm)']>5
# Out:
# setosa        True
# setosa       False
# setosa       False
# setosa       False
# setosa       False
#              ...
# virginica     True
# virginica     True
# virginica     True
# virginica     True
# virginica     True
# Name: sepal length (cm), Length: 150, dtype: bool

# %%
iris_table[(iris_table['sepal length (cm)'] > 5)]
# Out:
#            sepal length (cm)  sepal width (cm)  petal length (cm)  \
# setosa                   5.1               3.5                1.4
# setosa                   5.4               3.9                1.7
# setosa                   5.4               3.7                1.5
# setosa                   5.8               4.0                1.2
# setosa                   5.7               4.4                1.5
# ...                      ...               ...                ...
# virginica                6.7               3.0                5.2
# virginica                6.3               2.5                5.0
# virginica                6.5               3.0                5.2
# virginica                6.2               3.4                5.4
# virginica                5.9               3.0                5.1
#
#            petal width (cm)
# setosa                  0.2
# setosa                  0.4
# setosa                  0.2
# setosa                  0.2
# ...

# %%
iris_table["like"] = range(0,150)
iris_table
# Out:
#            sepal length (cm)  sepal width (cm)  petal length (cm)  \
# setosa                   5.1               3.5                1.4
# setosa                   4.9               3.0                1.4
# setosa                   4.7               3.2                1.3
# setosa                   4.6               3.1                1.5
# setosa                   5.0               3.6                1.4
# ...                      ...               ...                ...
# virginica                6.7               3.0                5.2
# virginica                6.3               2.5                5.0
# virginica                6.5               3.0                5.2
# virginica                6.2               3.4                5.4
# virginica                5.9               3.0                5.1
#
#            petal width (cm)  like
# setosa                  0.2     0
# setosa                  0.2     1
# setosa                  0.2     2
# ...

# %%
(iris_table.loc[:'setosa'])
# Out:
#         sepal length (cm)  sepal width (cm)  petal length (cm)  \
# setosa                5.1               3.5                1.4
# setosa                4.9               3.0                1.4
# setosa                4.7               3.2                1.3
# setosa                4.6               3.1                1.5
# setosa                5.0               3.6                1.4
# setosa                5.4               3.9                1.7
# setosa                4.6               3.4                1.4
# setosa                5.0               3.4                1.5
# setosa                4.4               2.9                1.4
# setosa                4.9               3.1                1.5
# setosa                5.4               3.7                1.5
# setosa                4.8               3.4                1.6
# setosa                4.8               3.0                1.4
# setosa                4.3               3.0                1.1
# ...

# %% [markdown]
# ## 11/15

# %%
type(iris_table.loc[:"sepal length (cm)"])
# Out:
# pandas.core.frame.DataFrame

# %%
iris_table
# Out:
#            sepal length (cm)  sepal width (cm)  petal length (cm)  \
# setosa                   5.1               3.5                1.4
# setosa                   4.9               3.0                1.4
# setosa                   4.7               3.2                1.3
# setosa                   4.6               3.1                1.5
# setosa                   5.0               3.6                1.4
# ...                      ...               ...                ...
# virginica                6.7               3.0                5.2
# virginica                6.3               2.5                5.0
# virginica                6.5               3.0                5.2
# virginica                6.2               3.4                5.4
# virginica                5.9               3.0                5.1
#
#            petal width (cm)  like
# setosa                  0.2     0
# setosa                  0.2     1
# setosa                  0.2     2
# ...

# %%
(iris_table.iloc[0,:])
# Out:
# sepal length (cm)    5.1
# sepal width (cm)     3.5
# petal length (cm)    1.4
# petal width (cm)     0.2
# like                 0.0
# Name: setosa, dtype: float64

# %%
(iris_table.iloc[0:2])
# Out:
#         sepal length (cm)  sepal width (cm)  petal length (cm)  \
# setosa                5.1               3.5                1.4
# setosa                4.9               3.0                1.4
#
#         petal width (cm)  like
# setosa               0.2     0
# setosa               0.2     1

# %%
iris_table.loc["setosa":"virginica"]
# Out:
#            sepal length (cm)  sepal width (cm)  petal length (cm)  \
# setosa                   5.1               3.5                1.4
# setosa                   4.9               3.0                1.4
# setosa                   4.7               3.2                1.3
# setosa                   4.6               3.1                1.5
# setosa                   5.0               3.6                1.4
# ...                      ...               ...                ...
# virginica                6.7               3.0                5.2
# virginica                6.3               2.5                5.0
# virginica                6.5               3.0                5.2
# virginica                6.2               3.4                5.4
# virginica                5.9               3.0                5.1
#
#            petal width (cm)  like
# setosa                  0.2     0
# setosa                  0.2     1
# setosa                  0.2     2
# ...

# %%
iris_table.iloc[[0,2,3]]
# Out:
#         sepal length (cm)  sepal width (cm)  petal length (cm)  \
# setosa                5.1               3.5                1.4
# setosa                4.7               3.2                1.3
# setosa                4.6               3.1                1.5
#
#         petal width (cm)  like
# setosa               0.2     0
# setosa               0.2     2
# setosa               0.2     3

# %% [markdown]
# ## 12/06

# %%
iris_table["sepal length (cm)"].describe()
# Out:
# count    150.000000
# mean       5.843333
# std        0.828066
# min        4.300000
# 25%        5.100000
# 50%        5.800000
# 75%        6.400000
# max        7.900000
# Name: sepal length (cm), dtype: float64

# %%
like_mean = iris_table.like.mean()
like_mean
# Out:
# np.float64(74.5)

# %%
iris_table
# Out:
#            sepal length (cm)  sepal width (cm)  petal length (cm)  \
# setosa                   5.1               3.5                1.4
# setosa                   4.9               3.0                1.4
# setosa                   4.7               3.2                1.3
# setosa                   4.6               3.1                1.5
# setosa                   5.0               3.6                1.4
# ...                      ...               ...                ...
# virginica                6.7               3.0                5.2
# virginica                6.3               2.5                5.0
# virginica                6.5               3.0                5.2
# virginica                6.2               3.4                5.4
# virginica                5.9               3.0                5.1
#
#            petal width (cm)  like
# setosa                  0.2     0
# setosa                  0.2     1
# setosa                  0.2     2
# ...

# %%
iris_table.like.map(lambda p:p-like_mean)
iris_table["sepal length (cm)"].mean()
# Out:
# np.float64(5.843333333333334)

# %%
#iris_table.like.map(lambda x:x-like_mean)

# %% [markdown]
# ### 12/13

# %%
iris_table.like = iris_table.like.map(lambda x: x-like_mean)
iris_table
# Out:
#            sepal length (cm)  sepal width (cm)  petal length (cm)  \
# setosa                   5.1               3.5                1.4
# setosa                   4.9               3.0                1.4
# setosa                   4.7               3.2                1.3
# setosa                   4.6               3.1                1.5
# setosa                   5.0               3.6                1.4
# ...                      ...               ...                ...
# virginica                6.7               3.0                5.2
# virginica                6.3               2.5                5.0
# virginica                6.5               3.0                5.2
# virginica                6.2               3.4                5.4
# virginica                5.9               3.0                5.1
#
#            petal width (cm)   like
# setosa                  0.2 -149.0
# setosa                  0.2 -148.0
# setosa                  0.2 -147.0
# ...

# %%
def remean(row):
    row.like -= like_mean
    row["sepal length (cm)"] -= 10
    return row
iris_table.apply(remean, axis = 1)
# Out:
#            sepal length (cm)  sepal width (cm)  petal length (cm)  \
# setosa                  -4.9               3.5                1.4
# setosa                  -5.1               3.0                1.4
# setosa                  -5.3               3.2                1.3
# setosa                  -5.4               3.1                1.5
# setosa                  -5.0               3.6                1.4
# ...                      ...               ...                ...
# virginica               -3.3               3.0                5.2
# virginica               -3.7               2.5                5.0
# virginica               -3.5               3.0                5.2
# virginica               -3.8               3.4                5.4
# virginica               -4.1               3.0                5.1
#
#            petal width (cm)   like
# setosa                  0.2 -223.5
# setosa                  0.2 -222.5
# setosa                  0.2 -221.5
# ...
